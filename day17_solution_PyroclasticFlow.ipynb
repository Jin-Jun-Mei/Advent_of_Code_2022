# %%
import itertools
from pathlib import Path
file_path = "C:/Users/jinxi/OneDrive - Chalmers/courses/2022_Advent_of_Code/"
file_name = "day17_input_data.txt"
file_name = "example.txt"
with open(Path(file_path + file_name)) as f:
    jet_pattern = f.read()
print(len(jet_pattern[0]))

# %%
def rock_fall(rock,jets,starting_pos):##first three vertical fall
    pass

# %%
rock_pattern = itertools.cycle(("-", "+", "j", "I", "o"))
# jet_pattern = itertools.cycle(jet_pattern)
jet_nr = itertools.cycle(range(len(jet_pattern)))
# for i in jet_pattern:
#     print(i)

# %%
highest_point = {j: 0 for j in range(1,7+1)} ##highest point for each column j.
starting_pos = (3,2)##starting position of rock 1.
shape = []

for m, rock, n in zip(range(2022),rock_pattern,jet_nr):
    jets = jet_pattern[n:n+3]
    h = rock_fall(rock,jets,starting_pos)
    starting_pos[0] += h #increase the row.
